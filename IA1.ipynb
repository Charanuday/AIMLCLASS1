# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
df=pd.read_csv("Downloads/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    146.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.045890       3.758667      1.198667
# std     43.445368       0.828066      0.424772       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.200000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   146 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['SepalLengthCm'])
# Out:
# pandas.core.series.Series

# %%
a=df['Species'].value_counts() 
a
plt.bar(a.index,a.values)
plt.title("count species")
plt.xlabel("species")
plt.ylabel("counts")
plt.show()

# %%
df=df['Species'].value_counts().plot(kind='bar')

# %%
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.show()

# %%
plt.hist(df['PetalLengthCm'],bins=5)
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalLengthCm counts")
plt.show()

# %%
import pandas as pd
df1=pd.read_csv("Downloads/weatherAUS.csv.zip")
df1
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  ... Pressure3pm  Cloud9am Cloud3pm Temp9am  Temp3pm  RainToday  RainTomorrow
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN  ...      1007.1       8.0      NaN    16.9     21.8         No            No
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN  ...      1007.8       NaN      NaN    17.2     24.3         No            No
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN  ...      1008.7       NaN      2.0    21.0     23.2         No            No
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN  ...      1012.8       NaN      NaN    18.1     26.5         No            No
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN  ...      1006.0       7.0      8.0    17.8     29.7         No            No
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   146 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df1['Rainfall'].max()
# Out:
# 371.0

# %%
df1.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  ... Pressure3pm  Cloud9am Cloud3pm Temp9am  Temp3pm  RainToday  RainTomorrow
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN  ...      1007.1       8.0      NaN    16.9     21.8         No            No
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN  ...      1007.8       NaN      NaN    17.2     24.3         No            No
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN  ...      1008.7       NaN      2.0    21.0     23.2         No            No
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN  ...      1012.8       NaN      NaN    18.1     26.5         No            No
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN  ...      1006.0       7.0      8.0    17.8     29.7         No            No
#
# [5 rows x 23 columns]

# %%
df1.groupby('Location')['Rainfall'].max()
# Out:
# Location
# Adelaide             75.2
# Albany               49.4
# Albury              104.2
# AliceSprings         62.0
# BadgerysCreek       116.0
# Ballarat             95.0
# Bendigo              66.4
# Brisbane            182.6
# Cairns              278.4
# Canberra             87.0
# Cobar                68.0
# CoffsHarbour        371.0
# Dartmoor             73.6
# Darwin              367.6
# GoldCoast           183.4
# Hobart               71.6
# Katherine           167.0
# Launceston           88.0
# Melbourne            82.2
# MelbourneAirport     75.8
# Mildura             155.0
# Moree               113.0
# MountGambier         84.6
# MountGinini         107.6
# Newcastle           240.0
# Nhil                 65.6
# NorahHead           126.4
# NorfolkIsland       156.8
# Nuriootpa            76.6
# PearceRAAF           62.4
# Penrith             115.4
# Perth               114.4
# PerthAirport         76.6
# Portland             72.0
# Richmond            113.4
# ...
