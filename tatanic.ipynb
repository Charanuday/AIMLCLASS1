# %%
import pandas as pd
df=pd.read_csv('Downloads/titanic.csv')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['Name']='gpt'

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name
# 0    man        True  NaN  Southampton    no  False  gpt
# 1  woman       False    C    Cherbourg   yes  False  gpt
# 2  woman       False  NaN  Southampton   yes   True  gpt
# 3  woman       False    C  Southampton   yes  False  gpt
# 4    man        True  NaN  Southampton    no   True  gpt

# %%
df['newfare']=df['fare']+10

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name  newfare
# 0    man        True  NaN  Southampton    no  False  gpt  17.2500
# 1  woman       False    C    Cherbourg   yes  False  gpt  81.2833
# 2  woman       False  NaN  Southampton   yes   True  gpt  17.9250
# 3  woman       False    C  Southampton   yes  False  gpt  63.1000
# 4    man        True  NaN  Southampton    no   True  gpt  18.0500

# %%
df['age catogary']=df['age'].apply(lambda x:'senior' if x >= 35 else 'juniour')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name  newfare age catogary
# 0    man        True  NaN  Southampton    no  False  gpt  17.2500      juniour
# 1  woman       False    C    Cherbourg   yes  False  gpt  81.2833       senior
# 2  woman       False  NaN  Southampton   yes   True  gpt  17.9250      juniour
# 3  woman       False    C  Southampton   yes  False  gpt  63.1000       senior
# 4    man        True  NaN  Southampton    no   True  gpt  18.0500       senior

# %%
df['survived']=df['survived'].apply(lambda x:'yes' if x >= 1 else 'No')
df.head()
# Out:
#   survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0       No       3    male  22.0      1      0   7.2500        S  Third
# 1      yes       1  female  38.0      1      0  71.2833        C  First
# 2      yes       3  female  26.0      0      0   7.9250        S  Third
# 3      yes       1  female  35.0      1      0  53.1000        S  First
# 4       No       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone Name  newfare age catogary
# 0    man        True  NaN  Southampton    no  False  gpt  17.2500      juniour
# 1  woman       False    C    Cherbourg   yes  False  gpt  81.2833       senior
# 2  woman       False  NaN  Southampton   yes   True  gpt  17.9250      juniour
# 3  woman       False    C  Southampton   yes  False  gpt  63.1000       senior
# 4    man        True  NaN  Southampton    no   True  gpt  18.0500       senior

# %%
df.drop('Name',axis=1)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         No       3    male  22.0      1      0   7.2500        S   Third
# 1        yes       1  female  38.0      1      0  71.2833        C   First
# 2        yes       3  female  26.0      0      0   7.9250        S   Third
# 3        yes       1  female  35.0      1      0  53.1000        S   First
# 4         No       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       No       2    male  27.0      0      0  13.0000        S  Second
# 887      yes       1  female  19.0      0      0  30.0000        S   First
# 888       No       3  female   NaN      1      2  23.4500        S   Third
# 889      yes       1    male  26.0      0      0  30.0000        C   First
# 890       No       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.drop(['age catogary','alone'],axis=1,inplace=True)
df
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         No       3    male  22.0      1      0   7.2500        S   Third
# 1        yes       1  female  38.0      1      0  71.2833        C   First
# 2        yes       3  female  26.0      0      0   7.9250        S   Third
# 3        yes       1  female  35.0      1      0  53.1000        S   First
# 4         No       3    male  35.0      0      0   8.0500        S   Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886       No       2    male  27.0      0      0  13.0000        S  Second
# 887      yes       1  female  19.0      0      0  30.0000        S   First
# 888       No       3  female   NaN      1      2  23.4500        S   Third
# 889      yes       1    male  26.0      0      0  30.0000        C   First
# 890       No       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive Name  newfare
# ...

# %%
df.drop(['sex','sibsp','parch','fare','embarked'],axis=1,inplace=True)

# %%
df
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 1        yes       1  38.0   First  woman       False    C    Cherbourg   yes
# 2        yes       3  26.0   Third  woman       False  NaN  Southampton   yes
# 3        yes       1  35.0   First  woman       False    C  Southampton   yes
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 888       No       3   NaN   Third  woman       False  NaN  Southampton    no
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df.loc(len[0])=["yes",1,34,"third","man","true","c","Southampton","yes","gpt",17.34]
# Out:
#   Cell In[56], line 1
#     df.loc(len[0])=["yes",1,34,"third","man","true","c","Southampton","yes","gpt",17.34]
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
df
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 1        yes       1  38.0   First  woman       False    C    Cherbourg   yes
# 2        yes       3  26.0   Third  woman       False  NaN  Southampton   yes
# 3        yes       1  35.0   First  woman       False    C  Southampton   yes
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 888       No       3   NaN   Third  woman       False  NaN  Southampton    no
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df.drop([1,2,3])
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# 5         No       3   NaN   Third    man        True  NaN   Queenstown    no
# 6         No       1  54.0   First    man        True    E  Southampton    no
# 7         No       3   2.0   Third  child       False  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 888       No       3   NaN   Third  woman       False  NaN  Southampton    no
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df=df[df["Name"]=="gpt"]
df
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 1        yes       1  38.0   First  woman       False    C    Cherbourg   yes
# 2        yes       3  26.0   Third  woman       False  NaN  Southampton   yes
# 3        yes       1  35.0   First  woman       False    C  Southampton   yes
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 888       No       3   NaN   Third  woman       False  NaN  Southampton    no
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df.head()
# Out:
#   survived  pclass   age  class    who  adult_male deck  embark_town alive  \
# 0       No       3  22.0  Third    man        True  NaN  Southampton    no
# 1      yes       1  38.0  First  woman       False    C    Cherbourg   yes
# 2      yes       3  26.0  Third  woman       False  NaN  Southampton   yes
# 3      yes       1  35.0  First  woman       False    C  Southampton   yes
# 4       No       3  35.0  Third    man        True  NaN  Southampton    no
#
#   Name  newfare
# 0  gpt  17.2500
# 1  gpt  81.2833
# 2  gpt  17.9250
# 3  gpt  63.1000
# 4  gpt  18.0500

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# age            177
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# Name             0
# newfare          0
# dtype: int64

# %%
df.drop('embark_town',axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df.drop('embark_town',axis=0,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df=df[df["survived"]!="NaN"]

# %%
df.head()
# Out:
#   survived  pclass   age  class    who  adult_male deck  embark_town alive  \
# 0       No       3  22.0  Third    man        True  NaN  Southampton    no
# 1      yes       1  38.0  First  woman       False    C    Cherbourg   yes
# 2      yes       3  26.0  Third  woman       False  NaN  Southampton   yes
# 3      yes       1  35.0  First  woman       False    C  Southampton   yes
# 4       No       3  35.0  Third    man        True  NaN  Southampton    no
#
#   Name  newfare
# 0  gpt  17.2500
# 1  gpt  81.2833
# 2  gpt  17.9250
# 3  gpt  63.1000
# 4  gpt  18.0500

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# age            177
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# Name             0
# newfare          0
# dtype: int64

# %%
df=df[df["age"]!="NaN"]

# %%
df
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 1        yes       1  38.0   First  woman       False    C    Cherbourg   yes
# 2        yes       3  26.0   Third  woman       False  NaN  Southampton   yes
# 3        yes       1  35.0   First  woman       False    C  Southampton   yes
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 888       No       3   NaN   Third  woman       False  NaN  Southampton    no
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df.isnull()
# Out:
#      survived  pclass    age  class    who  adult_male   deck  embark_town  \
# 0       False   False  False  False  False       False   True        False
# 1       False   False  False  False  False       False  False        False
# 2       False   False  False  False  False       False   True        False
# 3       False   False  False  False  False       False  False        False
# 4       False   False  False  False  False       False   True        False
# ..        ...     ...    ...    ...    ...         ...    ...          ...
# 886     False   False  False  False  False       False   True        False
# 887     False   False  False  False  False       False  False        False
# 888     False   False   True  False  False       False   True        False
# 889     False   False  False  False  False       False  False        False
# 890     False   False  False  False  False       False   True        False
#
#      alive   Name  newfare
# 0    False  False    False
# ...

# %%
df.dropna(subset=['age'])
# Out:
#     survived  pclass   age   class    who  adult_male deck  embark_town alive  \
# 0         No       3  22.0   Third    man        True  NaN  Southampton    no
# 1        yes       1  38.0   First  woman       False    C    Cherbourg   yes
# 2        yes       3  26.0   Third  woman       False  NaN  Southampton   yes
# 3        yes       1  35.0   First  woman       False    C  Southampton   yes
# 4         No       3  35.0   Third    man        True  NaN  Southampton    no
# ..       ...     ...   ...     ...    ...         ...  ...          ...   ...
# 885       No       3  39.0   Third  woman       False  NaN   Queenstown    no
# 886       No       2  27.0  Second    man        True  NaN  Southampton    no
# 887      yes       1  19.0   First  woman       False    B  Southampton   yes
# 889      yes       1  26.0   First    man        True    C    Cherbourg   yes
# 890       No       3  32.0   Third    man        True  NaN   Queenstown    no
#
#     Name  newfare
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# age            177
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# Name             0
# newfare          0
# dtype: int64

# %%
s
