# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("C:/Users/DELL/Downloads/titanic.csv")
print(df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Check for missing values

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Fill the missing values using mean

# %%
dc=df['age'].mean()
print(dc)
# Out:
# 29.69911764705882

# %%
df['age']=df['age'].fillna(dc)
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ##Fill the missing values using Mode and Meadin

# %%
dc=df['age'].mode()
print(dc)
# Out:
# 0    29.699118
# Name: age, dtype: float64

# %% [markdown]
# C) Filling the missin values using median and mode

# %%
df['deck']=df['deck'].fillna('C')
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
dc=df['deck'].mode()[0]
print(dc)
# Out:
# C

# %%
df.head(10)
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0         0       3    male  22.000000      1      0   7.2500        S
# 1         1       1  female  38.000000      1      0  71.2833        C
# 2         1       3  female  26.000000      0      0   7.9250        S
# 3         1       1  female  35.000000      1      0  53.1000        S
# 4         0       3    male  35.000000      0      0   8.0500        S
# 5         0       3    male  29.699118      0      0   8.4583        Q
# 6         0       1    male  54.000000      0      0  51.8625        S
# 7         0       3    male   2.000000      3      1  21.0750        S
# 8         1       3  female  27.000000      0      2  11.1333        S
# 9         1       2  female  14.000000      1      0  30.0708        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   Third    man        True    C  Southampton    no  False
# 1   First  woman       False    C    Cherbourg   yes  False
# ...

# %%
dc=df['age'].median()
print(dc)
# Out:
# 29.69911764705882

# %%
df['age']=df['age']
print(df)
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# Fill the missing the arbitor values

# %%
df['age'].plot(kind="box")
# Out:
# <Axes: >

# %%
plt.scatter(df['fare'],df['age'],marker='o',c='green')
plt.title('show age and fare in scaatter plot')
plt.xlabel('fare')
plt.ylabel('Age')
plt.show()

# %%
q1=df['age'].quantile(0.25)
q3=df['age'].quantile(0.75)

# %%
iqr=q3-q1

# %%
fare_arr=df['fare']
lower=np.percentile(fare_arr,1)
upper=np.percentile(fare_arr,99)
print("lower is ",lower)
print("upper is",upper)
# Out:
# lower is  0.0
# upper is 249.00622000000035

# %%
for i in df['fare']:
    if i < lower:
        df['fare']=df['fare'].replace(i,lower)
    elif i < upper:
        df['fare']=df['fare'].replace(i,upper)

df
# Out:
#      survived  pclass     sex        age  sibsp  parch       fare embarked  \
# 0           0       3    male  22.000000      1      0  249.00622        S
# 1           1       1  female  38.000000      1      0  249.00622        C
# 2           1       3  female  26.000000      0      0  249.00622        S
# 3           1       1  female  35.000000      1      0  249.00622        S
# 4           0       3    male  35.000000      0      0  249.00622        S
# ..        ...     ...     ...        ...    ...    ...        ...      ...
# 886         0       2    male  27.000000      0      0  249.00622        S
# 887         1       1  female  19.000000      0      0  249.00622        S
# 888         0       3  female  29.699118      1      2  249.00622        S
# 889         1       1    male  26.000000      0      0  249.00622        C
# 890         0       3    male  32.000000      0      0  249.00622        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head(30)
# Out:
#     survived  pclass     sex        age  sibsp  parch       fare embarked  \
# 0          0       3    male  22.000000      1      0  249.00622        S
# 1          1       1  female  38.000000      1      0  249.00622        C
# 2          1       3  female  26.000000      0      0  249.00622        S
# 3          1       1  female  35.000000      1      0  249.00622        S
# 4          0       3    male  35.000000      0      0  249.00622        S
# 5          0       3    male  29.699118      0      0  249.00622        Q
# 6          0       1    male  54.000000      0      0  249.00622        S
# 7          0       3    male   2.000000      3      1  249.00622        S
# 8          1       3  female  27.000000      0      2  249.00622        S
# 9          1       2  female  14.000000      1      0  249.00622        C
# 10         1       3  female   4.000000      1      1  249.00622        S
# 11         1       1  female  58.000000      0      0  249.00622        S
# ...

# %%
df.to_csv('Titanic_Dataset.csv',index=False)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0         0       3    male  22.0      1      0  249.00622        S  Third
# 1         1       1  female  38.0      1      0  249.00622        C  First
# 2         1       3  female  26.0      0      0  249.00622        S  Third
# 3         1       1  female  35.0      1      0  249.00622        S  First
# 4         0       3    male  35.0      0      0  249.00622        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch       fare embarked  class  \
# 0         0       3    male  22.0      1      0  249.00622        S  Third
# 1         1       1  female  38.0      1      0  249.00622        C  First
# 2         1       3  female  26.0      0      0  249.00622        S  Third
# 3         1       1  female  35.0      1      0  249.00622        S  First
# 4         0       3    male  35.0      0      0  249.00622        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True
